# %% [markdown]
# # Описание
#
# Один из возможных источников данных с адресами -- ГАР от ФИАС (https://fias.nalog.ru/Frontend). Однако здесь данные и избыточные для наших целей, и лежат в специфическом формате и скачиваются все одним архивом (размеров в сжатом виде в десятки, а в распакованном -- в сотни гигабайт). Поэтому посмотрим сперва на эти данные и поймём, как их можно обработать для наших целей.
#
# Предполагается, что мы заранее скачали архив по ссылке выше.

# %% [markdown]
# # Импорты

# %%
import zipfile
import os
from io import StringIO

import pandas as pd

# %%
path_to_archive = "E:\\!Storage\\ГАР\\gar_xml.zip"

# %% [markdown]
# # Данные

# %%
z = zipfile.ZipFile(path_to_archive)

# %%
z_files = sorted(z.namelist())

# %%
def load_dataset(zip_file, zip_path, key_col=None, end_col="ENDDATE"):
    actual_col = "ISACTUAL"
    ds = pd.read_xml(zip_file.open(zip_path), parser='etree')
    ds_filtered = ds
    if actual_col in ds:
        ds_filtered = ds[ds[actual_col] == 1]
    if (key_col is None) or (end_col not in ds):
        return ds_filtered
    return (
        ds_filtered
        .sort_values(end_col, ascending=False)
        .groupby(key_col, as_index=False)
        .first()
    )

# %%
root_files = [f for f in z_files if os.path.dirname(f) == ""]

# %% [markdown]
# ## Описание полей

# %%
root_files
# Out:
# ['AS_ADDHOUSE_TYPES_20250327_adbcfb0e-1d7f-4988-9355-44cbe3dd151f.XML',
#  'AS_ADDR_OBJ_TYPES_20250327_489d0f3f-f003-4017-9031-82f8f4b96672.XML',
#  'AS_APARTMENT_TYPES_20250327_ce5f2321-f6ee-4f47-b92e-fff9dd89f324.XML',
#  'AS_HOUSE_TYPES_20250327_bdc6731e-d51b-492c-aab4-3df2b1dca179.XML',
#  'AS_NORMATIVE_DOCS_KINDS_20250327_72ab1bd8-7ea9-4519-b16e-b74ec6d8fc86.XML',
#  'AS_NORMATIVE_DOCS_TYPES_20250327_b6e368b1-6bfb-422f-a92a-3824bb3d3d72.XML',
#  'AS_OBJECT_LEVELS_20250327_654536f3-fb92-4d71-ad62-86d4c405638c.XML',
#  'AS_OPERATION_TYPES_20250327_f2eafdcb-a047-472d-bb52-e130a3ad56f8.XML',
#  'AS_PARAM_TYPES_20250327_e0e1ab39-c33f-469c-8aaf-d7fd2e087578.XML',
#  'AS_ROOM_TYPES_20250327_5cc957c5-4332-4072-b1b0-4fbfab53f3b9.XML',
#  'version.txt']

# %%
path = root_files[0]
print(path)
load_dataset(z, path)
# Out:
# AS_ADDHOUSE_TYPES_20250327_adbcfb0e-1d7f-4988-9355-44cbe3dd151f.XML
#    ID        NAME SHORTNAME        DESC  ISACTIVE  UPDATEDATE   STARTDATE  \
# 0   1      Корпус        к.      Корпус      True  2015-12-25  2015-12-25
# 1   2    Строение      стр.    Строение      True  2015-12-25  2015-12-25
# 2   3  Сооружение     соор.  Сооружение      True  2015-12-25  2015-12-25
# 3   4      Литера    литера      Литера     False  1900-01-01  1900-01-01
#
#       ENDDATE
# 0  2079-06-06
# 1  2079-06-06
# 2  2079-06-06
# 3  2015-12-25

# %%
path = root_files[1]
print(path)
load_dataset(z, path)
# Out:
# AS_ADDR_OBJ_TYPES_20250327_489d0f3f-f003-4017-9031-82f8f4b96672.XML
#       ID  LEVEL                NAME SHORTNAME                DESC  UPDATEDATE  \
# 0      5      1  Автономная область      Аобл  Автономная область  1900-01-01
# 1      2      1  Автономная область    а.обл.  Автономная область  2015-11-05
# 2      4      1    Автономный округ        АО    Автономный округ  1900-01-01
# 3      3      1    Автономный округ    а.окр.    Автономный округ  2015-11-05
# 4      6      1               Город         г               Город  1900-01-01
# ..   ...    ...                 ...       ...                 ...         ...
# 418  410     16             Участок      уч-к             Участок  1900-01-01
# 419  411     16               Ферма     ферма               Ферма  1900-01-01
# 420  412     16               Хутор         х               Хутор  1900-01-01
# 421  413     16               Шоссе         ш               Шоссе  1900-01-01
# 422  227     17        Машино-место       м/м        Машино-место  2019-02-14
#
#       STARTDATE     ENDDATE  ISACTIVE
# 0    1900-01-01  2015-11-05      True
# 1    2015-11-05  2079-06-06      True
# 2    1900-01-01  2015-11-05      True
# 3    2015-11-05  2079-06-06      True
# 4    1900-01-01  2015-11-05      True
# ..          ...         ...       ...
# 418  1900-01-01  2015-12-31      True
# 419  1900-01-01  2015-12-31      True
# 420  1900-01-01  2079-06-06      True
# 421  1900-01-01  2079-06-06      True
# 422  2019-02-14  2079-06-06      True
#
# [423 rows x 9 columns]

# %%
path = root_files[3]
print(path)
load_dataset(z, path)
# Out:
# AS_HOUSE_TYPES_20250327_bdc6731e-d51b-492c-aab4-3df2b1dca179.XML
#     ID                                 NAME SHORTNAME  \
# 0    1                             Владение      влд.
# 1    2                                  Дом        д.
# 2    3                         Домовладение     двлд.
# 3    4                                Гараж       г-ж
# 4    5                               Здание       зд.
# 5    6                                Шахта     шахта
# 6    7                             Строение      стр.
# 7    8                           Сооружение     соор.
# 8    9                               Литера    литера
# 9   10                               Корпус        к.
# 10  11                               Подвал     подв.
# 11  12                            Котельная      кот.
# 12  13                               Погреб       п-б
# 13  14  Объект незавершенного строительства       ОНС
#
#                                    DESC  ISACTIVE  UPDATEDATE   STARTDATE  \
# 0                              Владение     False  1900-01-01  1900-01-01
# 1                                   Дом      True  1900-01-01  1900-01-01
# 2                          Домовладение     False  1900-01-01  1900-01-01
# 3                                 Гараж      True  1900-01-01  1900-01-01
# 4                                Здание      True  1900-01-01  1900-01-01
# 5                                 Шахта      True  1900-01-01  1900-01-01
# 6                              Строение      True  1900-01-01  1900-01-01
# 7                            Сооружение      True  1900-01-01  1900-01-01
# 8                                Литера     False  1900-01-01  1900-01-01
# 9                                Корпус      True  1900-01-01  1900-01-01
# 10                               Подвал     False  1900-01-01  1900-01-01
# 11                            Котельная     False  1900-01-01  1900-01-01
# 12                               Погреб     False  1900-01-01  1900-01-01
# 13  Объект незавершенного строительства     False  1900-01-01  1900-01-01
#
#        ENDDATE
# 0   2015-11-05
# 1   2079-06-06
# 2   2015-11-05
# 3   2079-06-06
# 4   2079-06-06
# 5   2079-06-06
# 6   2079-06-06
# 7   2079-06-06
# 8   2015-12-25
# 9   2079-06-06
# 10  2015-11-05
# 11  2015-11-05
# 12  2015-11-05
# 13  2015-11-05

# %%
path = root_files[6]
print(path)
load_dataset(z, path)
# Out:
# AS_OBJECT_LEVELS_20250327_654536f3-fb92-4d71-ad62-86d4c405638c.XML
#     LEVEL                                               NAME   STARTDATE  \
# 0       1                                         Субъект РФ  1900-01-01
# 1       2                             Административный район  1900-01-01
# 2       3                                Муниципальный район  1900-01-01
# 3       4                       Сельское/городское поселение  1900-01-01
# 4       5                                              Город  1900-01-01
# 5       6                                   Населенный пункт  1900-01-01
# 6       7                    Элемент планировочной структуры  1900-01-01
# 7       8                       Элемент улично-дорожной сети  1900-01-01
# 8       9                                  Земельный участок  1900-01-01
# 9      10                      Здание (строение), сооружение  1900-01-01
# 10     11                                          Помещение  1900-01-01
# 11     12                     Помещения в пределах помещения  1900-01-01
# 12     13            Уровень автономного округа (устаревшее)  1900-01-01
# 13     14    Уровень внутригородской территории (устаревшее)  1900-01-01
# 14     15     Уровень дополнительных территорий (устаревшее)  1900-01-01
# 15     16  Уровень объектов на дополнительных территориях...  1900-01-01
# 16     17                                       Машино-место  1900-01-01
#
#        ENDDATE  UPDATEDATE  ISACTIVE
# 0   2079-06-06  1900-01-01      True
# 1   2079-06-06  1900-01-01      True
# 2   2079-06-06  1900-01-01      True
# 3   2079-06-06  1900-01-01      True
# 4   2079-06-06  1900-01-01      True
# 5   2079-06-06  1900-01-01      True
# 6   2079-06-06  1900-01-01      True
# 7   2079-06-06  1900-01-01      True
# 8   2079-06-06  1900-01-01      True
# 9   2079-06-06  1900-01-01      True
# 10  2079-06-06  1900-01-01      True
# 11  2079-06-06  1900-01-01      True
# 12  2015-11-01  1900-01-01      True
# 13  2015-11-01  1900-01-01      True
# 14  2015-11-01  1900-01-01      True
# 15  2015-11-01  1900-01-01      True
# 16  2079-06-06  1900-01-01      True

# %%
path = root_files[7]
print(path)
load_dataset(z, path)
# Out:
# AS_OPERATION_TYPES_20250327_f2eafdcb-a047-472d-bb52-e130a3ad56f8.XML
#     ID                                               NAME  ISACTIVE  \
# 0    0                                      Не определено      True
# 1    1                                          Инициация      True
# 2   10                                         Добавление      True
# 3   20                                     Редактирование      True
# 4   21                                Групповое изменение      True
# 5   23                Редактирование протяжённых объектов      True
# 6   24                  Групповое редактирование объектов      True
# 7   25  Размещение сведений о почтовых индексах на осн...      True
# 8   26                       Обновление справочника ОКТМО      True
# 9   27                       Обновление справочника ОКАТО      True
# 10  28                        Обновление справочника СОУН      True
# 11  29                   Нормализация адресных параметров      True
# 12  30                                           Удаление      True
# 13  31  Удаление вследствие удаления вышестоящего объекта      True
# 14  32  Размещение сведений о кадастровых номерах на о...      True
# 15  33  Размещение сведений о кадастровых номерах на о...      True
# 16  40                                        Объединение      True
# 17  41  Переподчинение вследствие объединения вышестоя...      True
# 18  42   Прекращение существования вследствие объединения      True
# 19  43  Создание нового адресного объекта в результате...      True
# 20  44  Образование нового объекта в результате объеди...      True
# 21  45  Прекращение существования вследствие образован...      True
# 22  46  Прекращение существования вследствие образован...      True
# 23  47  Переподчинение в результате объединения машино...      True
# 24  50                                     Переподчинение      True
# 25  51  Переподчинение вследствие переподчинения вышес...      True
# 26  52  Прекращение существования вследствие переподчи...      True
# 27  53  Переподчинение вследствие изм.состава род.объе...      True
# 28  60    Прекращение существования вследствие разделения      True
# 29  61  Создание нового адресного объекта в результате...      True
# 30  70  Восстановление прекратившего существование объ...      True
# 31  71             Внесение признака корректности объекта      True
#
#     UPDATEDATE   STARTDATE     ENDDATE  \
# 0   1900-01-01  1900-01-01  2079-06-06
# 1   1900-01-01  1900-01-01  2079-06-06
# 2   1900-01-01  1900-01-01  2079-06-06
# 3   1900-01-01  1900-01-01  2079-06-06
# 4   1900-01-01  1900-01-01  2079-06-06
# 5   1900-01-01  1900-01-01  2079-06-06
# 6   1900-01-01  1900-01-01  2079-06-06
# 7   1900-01-01  1900-01-01  2079-06-06
# 8   1900-01-01  1900-01-01  2079-06-06
# 9   1900-01-01  1900-01-01  2079-06-06
# 10  1900-01-01  1900-01-01  2079-06-06
# 11  1900-01-01  1900-01-01  2079-06-06
# 12  1900-01-01  1900-01-01  2079-06-06
# 13  1900-01-01  1900-01-01  2079-06-06
# 14  1900-01-01  1900-01-01  2079-06-06
# 15  1900-01-01  1900-01-01  2079-06-06
# 16  1900-01-01  1900-01-01  2079-06-06
# 17  1900-01-01  1900-01-01  2079-06-06
# 18  1900-01-01  1900-01-01  2079-06-06
# 19  1900-01-01  1900-01-01  2079-06-06
# 20  1900-01-01  1900-01-01  2079-06-06
# 21  1900-01-01  1900-01-01  2079-06-06
# 22  1900-01-01  1900-01-01  2079-06-06
# 23  1900-01-01  1900-01-01  2079-06-06
# 24  1900-01-01  1900-01-01  2079-06-06
# 25  1900-01-01  1900-01-01  2079-06-06
# 26  1900-01-01  1900-01-01  2079-06-06
# 27  1900-01-01  1900-01-01  2079-06-06
# 28  1900-01-01  1900-01-01  2079-06-06
# 29  1900-01-01  1900-01-01  2079-06-06
# 30  1900-01-01  1900-01-01  2079-06-06
# 31  1900-01-01  1900-01-01  2079-06-06
#
#                                             SHORTNAME
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                 Групповое изменение
# 5                 Редактирование протяжённых объектов
# 6                   Групповое редактирование объектов
# 7   Размещение сведений о почтовых индексах на осн...
# 8                        Обновление справочника ОКТМО
# 9                        Обновление справочника ОКАТО
# 10                        Обновление справочника СОУН
# 11                                               None
# 12                                               None
# 13                                               None
# 14  Размещение сведений о кадастровых номерах на о...
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20  Образование нового объекта в результате объеди...
# 21  Прекращение существования вследствие образован...
# 22  Прекращение существования вследствие образован...
# 23  Переподчинение в результате объединения машино...
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31             Внесение признака корректности объекта

# %%
path = root_files[8]
print(path)
load_dataset(z, path)
# Out:
# AS_PARAM_TYPES_20250327_e0e1ab39-c33f-469c-8aaf-d7fd2e087578.XML
#     ID                                               NAME  \
# 0    1                                            ИФНС ФЛ
# 1    2                                            ИФНС ЮЛ
# 2    3                                     ИФНС ФЛ ТЕР УЧ
# 3    4                                     ИФНС ЮЛ ТЕР УЧ
# 4    5                                    Почтовый индекс
# 5    6                                              ОКАТО
# 6    7                                              OKTMO
# 7    8                                  Кадастровый номер
# 8   10                                          Код КЛАДР
# 9   11                Код КЛАДР без признака актуальности
# 10  12                                        Код региона
# 11  13                                   Реестровый номер
# 12  14                          Признак присвоения адреса
# 13  15                                   Порядковый номер
# 14  16                           Официальное наименование
# 15  17                  Статус обслуживания Почтой России
# 16  18            Признак корректности объекта (не дубль)
# 17  19                                Многоквартирный дом
# 18  20                   Дата снятия с кадастрового учета
# 19  21                            ОКТМО бюджетополучателя
# 20  22                 Административный центр субъекта РФ
# 21  23  Административный центр муниципального образования
#
#                                                  DESC  \
# 0                                             ИФНС ФЛ
# 1                                             ИФНС ЮЛ
# 2                     Территориальный участок ИФНС ФЛ
# 3                     Территориальный участок ИФНС ЮЛ
# 4                       Информация о почтовом индексе
# 5                                               ОКАТО
# 6                                               OKTMO
# 7                                   Кадастровый номер
# 8   Код адресного объекта одной строкой с признако...
# 9   Код адресного объекта одной строкой без призна...
# 10                                        Код региона
# 11                 Реестровый номер адресного объекта
# 12  Признак в каком делении присвоен адрес, муници...
# 13         Порядковый номер обьекта в рамках родителя
# 14          Официальное наименование объекта(Региона)
# 15                  Статус обслуживания Почтой России
# 16            Признак корректности объекта (не дубль)
# 17                                Многоквартирный дом
# 18                   Дата снятия с кадастрового учета
# 19                            ОКТМО бюджетополучателя
# 20                 Административный центр субъекта РФ
# 21  Административный центр муниципального образования
#
#                            CODE  ISACTIVE  UPDATEDATE   STARTDATE     ENDDATE
# 0                        IFNSFL      True  2018-06-15  2011-11-01  2079-06-06
# 1                        IFNSUL      True  2018-06-15  2011-11-01  2079-06-06
# 2         territorialifnsflcode      True  2018-06-15  2011-11-01  2079-06-06
# 3         territorialifnsulcode      True  2018-06-15  2011-11-01  2079-06-06
# 4                     PostIndex      True  2018-06-15  2011-11-01  2079-06-06
# 5                         OKATO      True  2018-06-19  2011-11-01  2079-06-06
# 6                         OKTMO      True  2018-06-19  2011-11-01  2079-06-06
# 7                    CadastrNum      True  2018-06-19  2011-11-01  2079-06-06
# 8                          CODE      True  2018-06-21  2011-11-01  2079-06-06
# 9                     PLAINCODE      True  2018-06-21  2011-11-01  2079-06-06
# 10                   REGIONCODE      True  2018-06-21  2011-11-01  2079-06-06
# 11                    ReestrNum      True  2018-11-12  2011-11-01  2079-06-06
# 12                 DivisionType      True  2018-12-14  2011-11-01  2079-06-06
# 13                      Counter      True  2018-12-14  2011-11-01  2079-06-06
# 14                     Official      True  2019-12-04  2019-12-04  2079-06-06
# 15                   PostStatus      True  2021-09-03  2021-09-03  2079-06-06
# 16                    IsCorrect      True  2022-03-25  2022-03-25  2079-06-06
# 17            ApartmentBuilding      True  2023-06-10  2023-06-10  2079-06-06
# 18  DateOfRemovalFromCadastrReg      True  2023-05-18  2023-05-18  2079-06-06
# 19                  OktmoBudget      True  2023-07-14  2023-07-14  2079-06-06
# 20                 IsAdmCapital      True  2024-09-28  2024-09-28  2079-06-06
# 21                 IsMunCapital      True  2024-09-28  2024-09-28  2079-06-06

# %%
path = root_files[9]
print(path)
load_dataset(z, path)
# Out:
# AS_ROOM_TYPES_20250327_5cc957c5-4332-4072-b1b0-4fbfab53f3b9.XML
#    ID           NAME           DESC  ISACTIVE   STARTDATE     ENDDATE  \
# 0   0  Не определено  Не определено      True  1900-01-01  2015-11-05
# 1   1        Комната        Комната      True  1900-01-01  2079-06-06
# 2   2      Помещение      Помещение      True  1900-01-01  2079-06-06
#
#    UPDATEDATE SHORTNAME
# 0  2011-01-01      None
# 1  2011-01-01      ком.
# 2  2011-01-01    помещ.

# %% [markdown]
# ## Изучение региона

# %% [markdown]
# Начнём с Москвы, как наиболее известного мне региона.

# %%
region_id = "77"

# %%
region_files = [f for f in z_files if os.path.dirname(f) == region_id]

# %%
region_files
# Out:
# ['77/AS_ADDR_OBJ_20250327_0fa4f946-e26b-435e-a465-6356525f2841.XML',
#  '77/AS_ADDR_OBJ_DIVISION_20250327_9e8334bd-b318-4ad9-b616-0d3ae0e08a56.XML',
#  '77/AS_ADDR_OBJ_PARAMS_20250327_2255531a-48ee-46af-86b0-ffe50c3e8dee.XML',
#  '77/AS_ADM_HIERARCHY_20250327_8ff210e4-2ec8-4f7b-801e-416214445482.XML',
#  '77/AS_APARTMENTS_20250327_29eafc2e-0d45-4083-8b30-6409a9cb6d5e.XML',
#  '77/AS_APARTMENTS_PARAMS_20250327_2832bf30-c3d0-48a5-9e8d-68bbaeff2099.XML',
#  '77/AS_CARPLACES_20250327_b4708798-9b61-4287-9b00-00cf3ebd6f1b.XML',
#  '77/AS_CARPLACES_PARAMS_20250327_8837e9cb-974d-4cca-99d8-56c0c4e23bfb.XML',
#  '77/AS_CHANGE_HISTORY_20250327_ee6555d3-5520-4f12-9e8f-e87bb9bd6ec7.XML',
#  '77/AS_HOUSES_20250327_5b78ff2c-2bdc-4d9c-a90e-52251767f462.XML',
#  '77/AS_HOUSES_PARAMS_20250327_592a46df-5bd7-440f-9dfe-3528dcea5af3.XML',
#  '77/AS_MUN_HIERARCHY_20250327_5aa56be4-6f00-48ce-b2ab-0bd07e705e3e.XML',
#  '77/AS_NORMATIVE_DOCS_20250327_212c647f-bb6d-40f1-a2cc-001c657f591c.XML',
#  '77/AS_REESTR_OBJECTS_20250327_bf484da9-d96d-43db-a1b0-037ceadd18e3.XML',
#  '77/AS_ROOMS_20250327_5f614ff2-99f1-4c38-b617-c55032c67b44.XML',
#  '77/AS_ROOMS_PARAMS_20250327_b81ddcaf-0a54-4103-aa73-93d876494d59.XML',
#  '77/AS_STEADS_20250327_44365dc6-6658-4b96-b01c-187e25d5a3ef.XML',
#  '77/AS_STEADS_PARAMS_20250327_72534af9-1cce-450a-80e2-89d1c52bf77a.XML']

# %% [markdown]
# ### Адресные объекты
#
# В `AS_ADDR_OBJ` лежат объекты, составляющие элементы адреса -- от региона и до улицы.

# %%
path = region_files[0]
print(path)
address_parts_dataset = load_dataset(z, path)
# Out:
# 77/AS_ADDR_OBJ_20250327_0fa4f946-e26b-435e-a465-6356525f2841.XML

# %%
address_parts_dataset.shape
# Out:
# (13313, 15)

# %%
address_parts_dataset.head()
# Out:
#          ID   OBJECTID                            OBJECTGUID   CHANGEID  \
# 1  52102410    1406821  c4c90184-8410-465b-938d-cdd362d241c3  591625953
# 2  52150772    1412644  0de928f6-3a67-497f-bb3d-d98d4785a2be  638391439
# 5  52150816  170040574  c6fbfb5b-6739-4c31-b84b-e5caaf73e85f  638395088
# 7  52150843  170042113  392525b8-aa87-46fb-ae8e-382116530438  638398563
# 8  52150858    1414020  3dc69326-4787-4992-b87c-0e34e742bf09  638399264
#
#                   NAME TYPENAME  LEVEL  OPERTYPEID    PREVID      NEXTID  \
# 1  Конструктора Лукина       ул      8          40   1731422         NaN
# 2                  108     кв-л      7          42   1738646  52150771.0
# 5                 131А     кв-л      7          40  52150624         NaN
# 7                  288     кв-л      7          40  52150671         NaN
# 8                   30     кв-л      7          42   1740499  52150857.0
#
#    UPDATEDATE   STARTDATE     ENDDATE  ISACTUAL  ISACTIVE
# 1  2024-03-13  2024-03-13  2079-06-06         1         1
# 2  2025-02-05  2025-02-05  2079-06-06         1         0
# 5  2025-02-05  2025-02-05  2079-06-06         1         1
# 7  2025-02-05  2025-02-05  2079-06-06         1         1
# 8  2025-02-05  2025-02-05  2079-06-06         1         0

# %%
address_parts_dataset.groupby(["ISACTUAL", "ISACTIVE"]).count()
# Out:
#                      ID  OBJECTID  OBJECTGUID  CHANGEID  NAME  TYPENAME  \
# ISACTUAL ISACTIVE
# 1        0         4484      4484        4484      4484  4484      4484
#          1         8829      8829        8829      8829  8829      8829
#
#                    LEVEL  OPERTYPEID  PREVID  NEXTID  UPDATEDATE  STARTDATE  \
# ISACTUAL ISACTIVE
# 1        0          4484        4484    4484    4482        4484       4484
#          1          8829        8829    8829    6666        8829       8829
#
#                    ENDDATE
# ISACTUAL ISACTIVE
# 1        0            4484
#          1            8829

# %%
address_parts_dataset[address_parts_dataset["LEVEL"] == 1]
# Out:
#            ID  OBJECTID                            OBJECTGUID  CHANGEID  \
# 9068  1729288   1405113  0c5b2444-70a0-4932-980c-b4dc0d3f02b5   3846120
#
#         NAME TYPENAME  LEVEL  OPERTYPEID  PREVID  NEXTID  UPDATEDATE  \
# 9068  Москва        г      1           1       0     0.0  2018-09-01
#
#        STARTDATE     ENDDATE  ISACTUAL  ISACTIVE
# 9068  1900-01-01  2079-06-06         1         1

# %%
for level in sorted(address_parts_dataset.LEVEL.unique()):
    types = sorted(address_parts_dataset[address_parts_dataset["LEVEL"] == level]["TYPENAME"].unique())
    print(level)
    print(types)
# Out:
# 1
# ['г']
# 2
# ['п', 'р-н']
# 3
# ['вн.тер.г.']
# 5
# ['г', 'г.', 'тер']
# 6
# ['д', 'дп', 'кв-л', 'нп', 'п', 'п/о', 'промзона', 'рп', 'с', 'тер', 'х']
# 7
# ['гск', 'днп', 'кв-л', 'м-ко', 'мкр', 'мкр.', 'н/п', 'наб.', 'парк', 'сквер', 'снт', 'тер', 'тер.', 'тер. ДНП', 'тер. ДНТ', 'тер. ДПК', 'тер. СНТ', 'тер. СПК', 'тер. ТСН', 'ш.']
# 8
# ['ал.', 'аллея', 'б-р', 'гск', 'д', 'дор', 'кв-л', 'км', 'линия', 'лн.', 'мкр', 'наб', 'наб.', 'нп', 'п', 'парк', 'пер', 'пер.', 'пл', 'пл.', 'платф', 'пр-д', 'пр-кт', 'проезд', 'просек', 'просека', 'проселок', 'проулок', 'с-р', 'снт', 'ст', 'стр', 'тер', 'туп', 'туп.', 'ул', 'ул.', 'уч-к', 'х', 'ш', 'ш.']
# 15
# ['гск', 'промзона', 'снт']

# %%
address_parts_dataset.groupby(
    "LEVEL"
)["ID"].count()
# Out:
# LEVEL
# 1        1
# 2       28
# 3      151
# 5        5
# 6      409
# 7     5882
# 8     6829
# 15       8
# Name: ID, dtype: int64

# %%
address_parts_dataset[address_parts_dataset["NAME"].str.contains("Ленин")]
# Out:
#              ID  OBJECTID                            OBJECTGUID   CHANGEID  \
# 481     1727092   1403313  9c3e9392-0324-4d21-9cf5-70076f1b5e15    3841514
# 553     1075954    870463  f168f4da-a379-46df-b4ce-0cf421ad7475    2407755
# 1253    1740905   1414349  c5fec714-04f5-4cb3-89d8-d7cec97116e6    3865610
# 5924    1728930   1404818  91ab1cb1-d0a4-489c-9182-9dfbabcd9e2b    3845389
# 7080    1863791    867679  7a8015ad-a3eb-4fd0-b4c4-c34ef55bb294  156242574
# 7605   52126950   1412966  e703d5fd-4655-48c9-8768-51a3818ebab1  601222326
# 8925    1732570   1407748  4350977e-e152-4018-a33d-b13143bbecda    3852507
# 9238    1726229   1402585  5f2a1243-a57b-418e-baee-ff76f4993b45    3839686
# 9952    1963016   1405058  12bf2472-62ee-4db6-b998-565141e7a9d1  289726664
# 10778   1739844   1413526  0faa0cfa-dfe8-4f5a-a001-2727a41d7f21    3864181
# 12992   1065298    864072  2417419d-a891-41b5-a9c4-7018283d01e3    2385113
# 14859   1740304   1413870  62d9bfcb-278d-48e6-ba60-c23e9776d305    3864794
# 15149   1731180   1406630  87674309-4a67-4fc3-9071-b9c6d70993b7    3849879
# 18440   1069963    866825  fdbcc75b-1ce8-4eec-b790-33a268df37ab    2394890
# 18807   1052487    856758  96f661a6-add6-4583-ba4b-6a7f9ef87a77    2357055
# 20043  52127206   1410733  051ce76a-0a0f-4234-a11b-dfa9b85bf6f8  601310070
# 21643   1734068   1408990  b05ce965-3bb0-4495-87f4-5eed877d3382    3855281
# 21941   1063663    863111  427d5fbf-f53c-43ee-a768-48a5cd49caf5    2381574
#
#                       NAME TYPENAME  LEVEL  OPERTYPEID   PREVID  NEXTID  \
# 481          Ленинградский    пр-кт      8           1        0     0.0
# 553                 Ленина       ул      8           1        0     0.0
# 1253         Ленинградское        ш      8           1        0     0.0
# 5924         Лениногорская       ул      8           1        0     0.0
# 7080                Ленина       ул      8          30  1071404     0.0
# 7605   СНТ Ленинское Знамя      тер      7          30  1739141     0.0
# 8925                Ленина       ул      8           1        0     0.0
# 9238             Ленинский    пр-кт      8           1        0     0.0
# 9952        Ленинские Горы       ул      8          30  1729220     0.0
# 10778               Ленина       ул      8           1        0     0.0
# 12992               Ленина       ул      8           1        0     0.0
# 14859    Ленинская Слобода       ул      8           1        0     0.0
# 15149       Ленинские Горы      тер      7          10        0     0.0
# 18440               Ленина       ул      8           1        0     0.0
# 18807               Ленина       ул      8          31  1052414     0.0
# 20043      Ленинское Знамя      снт      7          30  1736226     0.0
# 21643        Юных Ленинцев       ул      8           1        0     0.0
# 21941               Ленина       ул      8           1        0     0.0
#
#        UPDATEDATE   STARTDATE     ENDDATE  ISACTUAL  ISACTIVE
# 481    2016-05-17  1900-01-01  2079-06-06         1         1
# 553    2017-09-07  1900-01-01  2079-06-06         1         1
# 1253   2016-05-11  1900-01-01  2079-06-06         1         1
# 5924   2016-05-31  1900-01-01  2079-06-06         1         1
# 7080   2020-09-03  2020-09-03  2079-06-06         1         0
# 7605   2024-09-13  2024-09-13  2079-06-06         1         0
# 8925   2016-10-05  1900-01-01  2079-06-06         1         1
# 9238   2016-05-17  1900-01-01  2079-06-06         1         1
# 9952   2022-09-08  2022-09-08  2079-06-06         1         0
# 10778  2016-06-15  1900-01-01  2079-06-06         1         1
# 12992  2017-09-07  1900-01-01  2079-06-06         1         1
# 14859  2016-06-10  1900-01-01  2079-06-06         1         1
# 15149  2017-05-18  2017-02-03  2079-06-06         1         1
# 18440  2017-09-07  1900-01-01  2079-06-06         1         1
# 18807  2017-11-16  2012-09-17  2079-06-06         1         0
# 20043  2024-09-16  2024-09-16  2079-06-06         1         0
# 21643  2016-06-07  1900-01-01  2079-06-06         1         1
# 21941  2016-09-26  1900-01-01  2079-06-06         1         1

# %%
address_parts_dataset.groupby("OBJECTID").count()["ID"].value_counts()
# Out:
# ID
# 1    13313
# Name: count, dtype: int64

# %% [markdown]
# ### Дома

# %%
path = region_files[9]
print(path)
houses_dataset = load_dataset(z, path)
# Out:
# 77/AS_HOUSES_20250327_5b78ff2c-2bdc-4d9c-a90e-52251767f462.XML

# %%
houses_dataset.shape
# Out:
# (347713, 18)

# %%
houses_dataset.sample(10)
# Out:
#                ID  OBJECTID                            OBJECTGUID   CHANGEID  \
# 279655   48951830  80896577  1cee6571-6b4e-41d3-a42b-3a462b8c3027  120227288
# 14340    37425008  62272596  b2014108-aa47-43ca-b38a-bec470e0dfd3   92979928
# 192089  123551283  56266558  5c856f8a-0427-4ef1-9eec-78f9347091aa  456252075
# 283385   19723396  33167239  56ee3d84-5064-4493-8896-5683592ca258   50581778
# 295732   70220101  99508452  6bc996c3-1869-4b6e-b5a4-9034f3aa1b69  162786672
# 247898   50546568  83504973  3efa88c4-a6e1-4bf2-8f63-a9fa3c08a94a  124044336
# 170570  123906192  78156503  d8c0e1e9-3049-40dc-9eec-f89e289d2356  488529487
# 14939     8433792  15011701  8b870254-58ba-4017-9159-5257a259555a   23951343
# 463645   26891102  45024461  e48f38df-03c4-4865-9b4d-0002eb923f99   67845777
# 52008    13536471  22947336  6dbda1af-2dbe-4a0e-8910-4fbdf530dff5   35711962
#
#        HOUSENUM ADDNUM1  HOUSETYPE  ADDTYPE1  OPERTYPEID    PREVID  NEXTID  \
# 279655       12       1        2.0       2.0          10         0     0.0
# 14340         9       3        2.0       1.0          10         0     0.0
# 192089       12       1        2.0       2.0          30  33661148     0.0
# 283385       31      14        2.0       2.0          10         0     0.0
# 295732       8А    None        2.0       NaN          10         0     0.0
# 247898      104       1        1.0       2.0          10         0     0.0
# 170570        8      17        2.0       2.0          30  47219618     0.0
# 14939       17А    None        2.0       NaN          10         0     0.0
# 463645      107    None        3.0       NaN          30  26891094     0.0
# 52008      None     598        NaN       2.0          30  13536100     0.0
#
#         UPDATEDATE   STARTDATE     ENDDATE  ISACTUAL  ISACTIVE ADDNUM2  \
# 279655  2018-04-27  2018-04-27  2079-06-06         1         1    None
# 14340   2017-12-18  1900-01-01  2079-06-06         1         1    None
# 192089  2022-10-17  2022-10-17  2079-06-06         1         0    None
# 283385  2011-11-24  1900-01-01  2079-06-06         1         1    None
# 295732  2020-12-09  2020-12-09  2079-06-06         1         1    None
# 247898  2019-04-08  2019-03-26  2079-06-06         1         1    None
# 170570  2022-12-01  2022-12-01  2079-06-06         1         0    None
# 14939   2012-02-27  1900-01-01  2079-06-06         1         1    None
# 463645  2019-06-14  2019-06-11  2019-06-11         1         0    None
# 52008   2019-09-11  2019-09-10  2019-09-10         1         0    None
#
#         ADDTYPE2
# 279655       NaN
# 14340        NaN
# 192089       NaN
# 283385       NaN
# 295732       NaN
# 247898       NaN
# 170570       NaN
# 14939        NaN
# 463645       NaN
# 52008        NaN

# %%
houses_dataset.groupby("OBJECTID").count()["ID"].value_counts()
# Out:
# ID
# 1    347713
# Name: count, dtype: int64

# %% [markdown]
# ### Административная иерархия

# %%
path = region_files[3]
print(path)
adm_dataset = load_dataset(z, path, "OBJECTID")
# Out:
# 77/AS_ADM_HIERARCHY_20250327_8ff210e4-2ec8-4f7b-801e-416214445482.XML

# %%
adm_dataset.shape
# Out:
# (8514060, 17)

# %%
adm_dataset.sample(10)
# Out:
#                 ID   OBJECTID  PARENTOBJID   CHANGEID  REGIONCODE     PREVID  \
# 4904264   99311830   28698223     28695987   44105360          77          0
# 2674048   95758180   18439422     18427920   29021221          77          0
# 312245    78751483   17257006     17236946   27276749          77          0
# 5719414  116594165   99399751     71536994  161335724          77          0
# 7486766  239988941  164109033    164103251  614020083          77  234338442
# 2004903   94369659   59212437     59210833   88455689          77          0
# 5592629  114732482   97627483     84228669  153832216          77          0
# 3914921   97275686   67879448     67866019  101192993          77          0
# 777376    90977175   62467243     62461753   93256664          77          0
# 980826    91522633   51480313     51442391   77177736          77          0
#
#             NEXTID  UPDATEDATE   STARTDATE     ENDDATE  ISACTIVE  \
# 4904264          0  1900-01-01  1900-01-01  2079-06-06         1
# 2674048          0  1900-01-01  1900-01-01  2079-06-06         1
# 312245           0  2012-07-01  2012-07-01  2012-07-01         0
# 5719414          0  2020-12-02  2020-12-02  2079-06-06         1
# 7486766  240657812  2025-01-17  2024-12-27  2025-01-17         0
# 2004903          0  1900-01-01  1900-01-01  2079-06-06         1
# 5592629          0  2020-07-23  2020-07-23  2079-06-06         1
# 3914921          0  1900-01-01  1900-01-01  2079-06-06         1
# 777376           0  1900-01-01  1900-01-01  2079-06-06         1
# 980826           0  1900-01-01  1900-01-01  2079-06-06         1
#
#                                             PATH  AREACODE  CITYCODE  \
# 4904264        1405113.1414511.28695987.28698223       NaN       NaN
# 2674048        1405113.1405805.18427920.18439422       NaN       NaN
# 312245   1405113.811011.812759.17236946.17257006       NaN       NaN
# 5719414        1405113.1409379.71536994.99399751       NaN       NaN
# 7486766    1405113.105530134.164103251.164109033       0.0       0.0
# 2004903        1405113.1405171.59210833.59212437       NaN       NaN
# 5592629        1405113.1402585.84228669.97627483       NaN       NaN
# 3914921        1405113.1411492.67866019.67879448       NaN       NaN
# 777376         1405113.1400892.62461753.62467243       NaN       NaN
# 980826         1405113.1401048.51442391.51480313       NaN       NaN
#
#          PLACECODE  PLANCODE  STREETCODE
# 4904264        NaN       NaN         NaN
# 2674048        NaN       NaN         NaN
# 312245         NaN       NaN         NaN
# 5719414        NaN       NaN         NaN
# 7486766        0.0       0.0      1332.0
# 2004903        NaN       NaN         NaN
# 5592629        NaN       NaN         NaN
# 3914921        NaN       NaN         NaN
# 777376         NaN       NaN         NaN
# 980826         NaN       NaN         NaN

# %% [markdown]
# Рассмотрим улицу Дмитрия Ульянова.

# %%
object_id = 1406744

# %%
address_parts_dataset[address_parts_dataset["OBJECTID"] == object_id]
# Out:
#             ID  OBJECTID                            OBJECTGUID  CHANGEID  \
# 18855  1731326   1406744  5c98ab12-a4e9-4a94-a08c-5c41469aeb1f   3850156
#
#                    NAME TYPENAME  LEVEL  OPERTYPEID  PREVID  NEXTID  \
# 18855  Дмитрия Ульянова       ул      8           1       0     0.0
#
#        UPDATEDATE   STARTDATE     ENDDATE  ISACTUAL  ISACTIVE
# 18855  2016-06-10  1900-01-01  2079-06-06         1         1

# %% [markdown]
# Её родитель в иерархии -- город Москва.

# %%
adm_dataset[adm_dataset["OBJECTID"] == object_id]
# Out:
#       OBJECTID         ID  PARENTOBJID   CHANGEID  REGIONCODE    PREVID  \
# 4742   1406744  114980138      1405113  154408041          77  95328001
#
#       NEXTID  UPDATEDATE   STARTDATE     ENDDATE  ISACTIVE             PATH  \
# 4742       0  2020-08-11  2020-08-11  2079-06-06         1  1405113.1406744
#
#       AREACODE  CITYCODE  PLACECODE  PLANCODE  STREETCODE
# 4742       0.0       0.0        0.0       0.0      2964.0

# %%
address_parts_dataset[address_parts_dataset["OBJECTID"] == 1405113]
# Out:
#            ID  OBJECTID                            OBJECTGUID  CHANGEID  \
# 9068  1729288   1405113  0c5b2444-70a0-4932-980c-b4dc0d3f02b5   3846120
#
#         NAME TYPENAME  LEVEL  OPERTYPEID  PREVID  NEXTID  UPDATEDATE  \
# 9068  Москва        г      1           1       0     0.0  2018-09-01
#
#        STARTDATE     ENDDATE  ISACTUAL  ISACTIVE
# 9068  1900-01-01  2079-06-06         1         1

# %% [markdown]
# Детей у неё много:

# %%
adm_dataset[adm_dataset["PARENTOBJID"] == object_id]
# Out:
#           OBJECTID         ID  PARENTOBJID   CHANGEID  REGIONCODE  PREVID  \
# 1620692   31075780   95328007      1406744   47547182          77       0
# 1620862   31081014   95328055      1406744   47554656          77       0
# 1622223   31108141   95328300      1406744   47592246          77       0
# 1622660   31114645   95328364      1406744   47602143          77       0
# 1622685   31115172   95328366      1406744   47603046          77       0
# ...            ...        ...          ...        ...         ...     ...
# 6539197  164953656  235321426      1406744  600196914          77       0
# 6539208  164953939  235321709      1406744  600197809          77       0
# 6539209  164953950  235321720      1406744  600197824          77       0
# 6539210  164953951  235321721      1406744  600197825          77       0
# 6539211  164953952  235321722      1406744  600197826          77       0
#
#          NEXTID  UPDATEDATE   STARTDATE     ENDDATE  ISACTIVE  \
# 1620692       0  1900-01-01  1900-01-01  2079-06-06         1
# 1620862       0  1900-01-01  1900-01-01  2079-06-06         1
# 1622223       0  1900-01-01  1900-01-01  2079-06-06         1
# 1622660       0  1900-01-01  1900-01-01  2079-06-06         1
# 1622685       0  1900-01-01  1900-01-01  2079-06-06         1
# ...         ...         ...         ...         ...       ...
# 6539197       0  2024-08-30  2024-08-30  2079-06-06         1
# 6539208       0  2024-08-30  2024-08-30  2079-06-06         1
# 6539209       0  2024-08-30  2024-08-30  2079-06-06         1
# 6539210       0  2024-08-30  2024-08-30  2079-06-06         1
# 6539211       0  2024-08-30  2024-08-30  2079-06-06         1
#
#                               PATH  AREACODE  CITYCODE  PLACECODE  PLANCODE  \
# 1620692   1405113.1406744.31075780       NaN       NaN        NaN       NaN
# 1620862   1405113.1406744.31081014       NaN       NaN        NaN       NaN
# 1622223   1405113.1406744.31108141       NaN       NaN        NaN       NaN
# 1622660   1405113.1406744.31114645       NaN       NaN        NaN       NaN
# 1622685   1405113.1406744.31115172       NaN       NaN        NaN       NaN
# ...                            ...       ...       ...        ...       ...
# 6539197  1405113.1406744.164953656       0.0       0.0        0.0       0.0
# 6539208  1405113.1406744.164953939       0.0       0.0        0.0       0.0
# 6539209  1405113.1406744.164953950       0.0       0.0        0.0       0.0
# 6539210  1405113.1406744.164953951       0.0       0.0        0.0       0.0
# 6539211  1405113.1406744.164953952       0.0       0.0        0.0       0.0
#
#          STREETCODE
# 1620692         NaN
# 1620862         NaN
# 1622223         NaN
# 1622660         NaN
# 1622685         NaN
# ...             ...
# 6539197      2964.0
# 6539208      2964.0
# 6539209      2964.0
# 6539210      2964.0
# 6539211      2964.0
#
# [170 rows x 17 columns]

# %% [markdown]
# Часть из них -- дома.

# %%
houses_dataset[houses_dataset["OBJECTID"] == 31075780]
# Out:
#               ID  OBJECTID                            OBJECTGUID  CHANGEID  \
# 407579  18446079  31075780  984e82d0-f541-4c97-8812-63d0972e8aba  47547182
#
#        HOUSENUM ADDNUM1  HOUSETYPE  ADDTYPE1  OPERTYPEID  PREVID  NEXTID  \
# 407579       12       1        2.0       1.0          10       0     0.0
#
#         UPDATEDATE   STARTDATE     ENDDATE  ISACTUAL  ISACTIVE ADDNUM2  \
# 407579  2019-02-23  1900-01-01  2079-06-06         1         1    None
#
#         ADDTYPE2
# 407579       NaN

# %% [markdown]
# А вот часть -- что-то непонятное.

# %%
houses_dataset[houses_dataset["OBJECTID"] == 164953952]
# Out:
# Empty DataFrame
# Columns: [ID, OBJECTID, OBJECTGUID, CHANGEID, HOUSENUM, ADDNUM1, HOUSETYPE, ADDTYPE1, OPERTYPEID, PREVID, NEXTID, UPDATEDATE, STARTDATE, ENDDATE, ISACTUAL, ISACTIVE, ADDNUM2, ADDTYPE2]
# Index: []

# %% [markdown]
# А все ли дома есть в этой иерарахии? Да.

# %%
houses_dataset["OBJECTID"].isin(adm_dataset["OBJECTID"]).sum() / len(houses_dataset)
# Out:
# np.float64(1.0)

# %% [markdown]
# ### Муниципальная иерархия

# %%
# %%time
path = region_files[11]
print(path)
mun_dataset = load_dataset(z, path, "OBJECTID")
# Out:
# 77/AS_MUN_HIERARCHY_20250327_5aa56be4-6f00-48ce-b2ab-0bd07e705e3e.XML
# CPU times: total: 4min 5s
# Wall time: 4min 7s

# %%
mun_dataset.shape
# Out:
# (6733085, 12)

# %%
mun_dataset.sample(10)
# Out:
#           OBJECTID         ID  PARENTOBJID   CHANGEID     OKTMO     PREVID  \
# 6379618  162029989  242893101     856205.0  619743036  45963000  230647715
# 778436    16065471   56927658   16064273.0   25524832  45340000          0
# 4365594   76154621   58437235   76150228.0  113282418  45305000          0
# 413646     9393959   54317783    9391924.0   15651623  45338000          0
# 4205357   72859209   58206408   72854703.0  108492749  45328000          0
# 1083671   21347462   54226810   21339695.0   33344609  45320000          0
# 6245376  160252159  240031821  160243856.0  614042523  45941000  228327855
# 6208660  159617149  227679674  159595539.0  507720805  45365000          0
# 1631858   31365904   57753639   31364281.0   47975740  45301000          0
# 3179134   58231004   54401369   58216714.0   87037646  45380000          0
#
#          NEXTID  UPDATEDATE   STARTDATE     ENDDATE  ISACTIVE  \
# 6379618       0  2025-01-27  2025-01-27  2079-06-06         1
# 778436        0  1900-01-01  1900-01-01  2079-06-06         1
# 4365594       0  1900-01-01  1900-01-01  2079-06-06         1
# 413646        0  1900-01-01  1900-01-01  2079-06-06         1
# 4205357       0  1900-01-01  1900-01-01  2079-06-06         1
# 1083671       0  1900-01-01  1900-01-01  2079-06-06         1
# 6245376       0  2024-12-27  2024-12-27  2079-06-06         1
# 6208660       0  2023-08-08  2023-08-08  2079-06-06         1
# 1631858       0  1900-01-01  1900-01-01  2079-06-06         1
# 3179134       0  1900-01-01  1900-01-01  2079-06-06         1
#
#                                                    PATH
# 6379618              1405113.169225309.856205.162029989
# 778436       1405113.95251332.1409529.16064273.16065471
# 4365594      1405113.95251250.1418586.76150228.76154621
# 413646         1405113.95251236.1399289.9391924.9393959
# 4205357      1405113.95251283.1415104.72854703.72859209
# 1083671      1405113.95251379.1400143.21339695.21347462
# 6245376  1405113.95251378.103564290.160243856.160252159
# 6208660    1405113.95251305.1410543.159595539.159617149
# 1631858      1405113.95251292.1412327.31364281.31365904
# 3179134      1405113.95251325.1402317.58216714.58231004

# %% [markdown]
# Рассмотрим опять улицу Дмитрия Ульянова.

# %%
object_id = 1406744

# %%
address_parts_dataset[address_parts_dataset["OBJECTID"] == object_id]
# Out:
#             ID  OBJECTID                            OBJECTGUID  CHANGEID  \
# 18855  1731326   1406744  5c98ab12-a4e9-4a94-a08c-5c41469aeb1f   3850156
#
#                    NAME TYPENAME  LEVEL  OPERTYPEID  PREVID  NEXTID  \
# 18855  Дмитрия Ульянова       ул      8           1       0     0.0
#
#        UPDATEDATE   STARTDATE     ENDDATE  ISACTUAL  ISACTIVE
# 18855  2016-06-10  1900-01-01  2079-06-06         1         1

# %% [markdown]
# Теперь у неё родитель не сразу город, а муниципальный округ (а где район?).

# %%
mun_dataset[mun_dataset["OBJECTID"] == object_id]
# Out:
#       OBJECTID        ID  PARENTOBJID  CHANGEID     OKTMO  PREVID  NEXTID  \
# 4587   1406744  55907563   95251310.0  48103478  45397000       0       0
#
#       UPDATEDATE   STARTDATE     ENDDATE  ISACTIVE                      PATH
# 4587  1900-01-01  1900-01-01  2079-06-06         1  1405113.95251310.1406744

# %%
address_parts_dataset[address_parts_dataset["OBJECTID"] == 95251310]
# Out:
#           ID  OBJECTID                            OBJECTGUID   CHANGEID  \
# 724  1823207  95251310  93876799-dd40-4f50-ba4e-0edfb6ea2ed6  138207827
#
#                                   NAME   TYPENAME  LEVEL  OPERTYPEID  PREVID  \
# 724  муниципальный округ Академический  вн.тер.г.      3           0       0
#
#      NEXTID  UPDATEDATE   STARTDATE     ENDDATE  ISACTUAL  ISACTIVE
# 724     0.0  2011-01-01  2011-01-01  2079-06-06         1         1

# %%
mun_dataset[mun_dataset["OBJECTID"] == 31075780]
# Out:
#          OBJECTID        ID  PARENTOBJID  CHANGEID     OKTMO  PREVID  NEXTID  \
# 1620131  31075780  55910706    1406744.0  47547182  45397000       0       0
#
#          UPDATEDATE   STARTDATE     ENDDATE  ISACTIVE  \
# 1620131  1900-01-01  1900-01-01  2079-06-06         1
#
#                                       PATH
# 1620131  1405113.95251310.1406744.31075780

# %% [markdown]
# А все ли дома есть в этой иерарахии? Нет.

# %%
houses_dataset["OBJECTID"].isin(mun_dataset["OBJECTID"]).sum() / len(houses_dataset)
# Out:
# np.float64(0.9979782176680193)

# %% [markdown]
# Посмотрим на не попавшие. В административной-то они были все.
#
# Во-первых, многие из них просроченные.

# %%
houses_dataset[~houses_dataset["OBJECTID"].isin(mun_dataset["OBJECTID"])]["ENDDATE"].value_counts().head()
# Out:
# ENDDATE
# 2019-09-25    201
# 2019-09-27    119
# 2019-06-10     88
# 2079-06-06     81
# 2019-12-25     32
# Name: count, dtype: int64

# %% [markdown]
# Во-вторых, все они не активные.

# %%
houses_dataset[~houses_dataset["OBJECTID"].isin(mun_dataset["OBJECTID"])]["ISACTIVE"].value_counts()
# Out:
# ISACTIVE
# 0    703
# Name: count, dtype: int64

# %% [markdown]
# ### Несколько общих проверок

# %% [markdown]
# Поищем районы

# %%
address_parts_dataset[address_parts_dataset["NAME"].apply(lambda x: "зюзино" in x.lower())]
# Out:
#            ID  OBJECTID                            OBJECTGUID   CHANGEID  \
# 9888  1823248  95251351  a4ea3c59-9eec-4931-a785-fb458d93ed46  138207868
#
#                             NAME   TYPENAME  LEVEL  OPERTYPEID  PREVID  \
# 9888  муниципальный округ Зюзино  вн.тер.г.      3           0       0
#
#       NEXTID  UPDATEDATE   STARTDATE     ENDDATE  ISACTUAL  ISACTIVE
# 9888     0.0  2011-01-01  2011-01-01  2079-06-06         1         1

# %%
address_parts_dataset[address_parts_dataset["NAME"].apply(lambda x: "раменки" in x.lower())]
# Out:
#            ID  OBJECTID                            OBJECTGUID   CHANGEID  \
# 1187  1823154  95251257  fa227bf3-8a4d-4ef5-80ce-7414fd01b4e7  138207774
# 3106  1726638   1402920  0a7df3d5-00d7-4c57-aec6-50cee6295efa    3840615
#
#                              NAME   TYPENAME  LEVEL  OPERTYPEID  PREVID  \
# 1187  муниципальный округ Раменки  вн.тер.г.      3           0       0
# 3106                      Раменки         ул      8           1       0
#
#       NEXTID  UPDATEDATE   STARTDATE     ENDDATE  ISACTUAL  ISACTIVE
# 1187     0.0  2011-01-01  2011-01-01  2079-06-06         1         1
# 3106     0.0  2016-06-16  1900-01-01  2079-06-06         1         1

# %% [markdown]
# Поищем странные улицы

# %%
address_parts_dataset[address_parts_dataset["NAME"].apply(lambda x: "рощи" in x.lower())]
# Out:
#             ID  OBJECTID                            OBJECTGUID   CHANGEID  \
# 368    1862744   1407043  0457a0af-63d7-45f0-8fe2-1d248db95b3b  156164442
# 1138   1862738   1408473  e9e758bc-3cbd-4987-8466-d3e15310092c  156164367
# 1146   1729266   1405091  50176aad-698f-428b-8b44-863e1009c624    3846086
# 1169   1862748   1400185  27030e76-05b0-470d-8bd0-39af5b01bcd3  156164447
# 1811   1862747   1403708  3f418142-9996-4e92-b84d-df63ebadc5c3  156164446
# 2258   1732433   1407631  f17fb4b1-da62-4429-a457-b66b10dfde74    3852239
# 2394   1732804   1407941  247c3930-76d0-4b72-9edf-1e752436842e    3852926
# 2936   1864701   1412892  f6128e27-8bde-4a04-a379-350370ee8efe  156331586
# 3208   1732935   1408048  c07f0f7f-a93f-47e7-90ca-dd6533174b19    3853162
# 3763   1727380   1403489  b9a7c624-24e6-423d-befa-e66e4c2faa53    3842120
# 4546   1861965   1403778  cea40393-c7e9-403d-aa78-2c87af3c6ccd  156059068
# 5923   1862751   1401042  e1175560-e51e-40f5-b82d-7d9fde1ef0b2  156164451
# 6030   1862753   1403560  2b2118fc-671f-4d61-8d4c-db81c765d9df  156164453
# 7344   1862739   1404223  6af63021-b920-4315-a6fc-b0f68107cac5  156164368
# 8804   1863255   1409552  85c31f37-4ab7-4382-8163-5483564163d8  156197321
# 8810   1862750   1408511  d7ea8ca6-f459-40a9-81eb-2bf461ce858c  156164450
# 9401   1862752   1402023  6ec7c75e-d77e-436c-905d-f8b10f4ad37d  156164452
# 9454   1862740   1408629  2de553d0-12f6-4d2b-9632-a835075b2bcd  156164369
# 10149  1862749   1420029  f324dd36-4dfa-41ca-bf32-e1a8755aa3c0  156164449
# 11490  1861964   1417924  7e3f6b49-42e3-4a7d-a439-86a26341a295  156059061
# 13552  1862745   1410378  f24f3e46-cd68-4d7c-b4e0-c49fc23442e1  156164444
# 13592  1862743   1405844  733e3730-09b8-4d9a-af08-7bf1a47309ff  156164440
# 17658  1862742   1404059  51ddb650-373d-4045-b547-6cefdd044fcd  156164371
# 18150  1864700   1406249  4947b1fc-a10f-4af3-be71-f547e46434af  156331585
# 19796  1861966   1410079  5f6e3c5a-285d-4b48-b8e5-e41b82270d7b  156059074
# 19808  1862746   1413321  4075ad6c-cdcc-400d-bc34-199ae15733ee  156164445
# 20434  1861984   1402690  5e1482c5-4be1-4644-900e-4dc613570e11  156061398
# 21082  1861963   1408596  a8796fa3-c903-4334-af78-e960e33c6f2e  156059055
# 21934  1862741   1407865  436b6b5f-8ef2-4913-a3c3-661dfb793822  156164370
#
#                      NAME TYPENAME  LEVEL  OPERTYPEID   PREVID  NEXTID  \
# 368     2-й Марьиной Рощи   проезд      8          20  1731686     NaN
# 1138   10-й Марьиной Рощи   проезд      8          20  1733446     NaN
# 1146         Дубовой Рощи   проезд      8           1        0     0.0
# 1169    4-я Марьиной Рощи       ул      8          20  1723328     NaN
# 1811    4-й Марьиной Рощи   проезд      8          20  1727572     NaN
# 2258   Марьиной Рощи 15-й   проезд      8          30  1732420     0.0
# 2394         Дубовой Рощи       ул      8           1        0     0.0
# 2936        4-й Рощинский   проезд      8          23  1738981     NaN
# 3208    Марьиной Рощи 3-й   проезд      8           1        0     0.0
# 3763       Берёзовой Рощи   проезд      8          20  1727311     0.0
# 4546        5-й Рощинский   проезд      8          20  1727659     NaN
# 5923    7-й Марьиной Рощи   проезд      8          20  1724361     NaN
# 6030    9-й Марьиной Рощи   проезд      8          20  1727401     NaN
# 7344   11-й Марьиной Рощи   проезд      8          20  1728190     NaN
# 8804    1-й Марьиной Рощи   проезд      8          20  1734734     NaN
# 8810    6-й Марьиной Рощи   проезд      8          20  1733490     NaN
# 9401    8-й Марьиной Рощи   проезд      8          20  1725547     NaN
# 9454   12-й Марьиной Рощи   проезд      8          20  1733634     NaN
# 10149   5-й Марьиной Рощи   проезд      8          20  1748303     NaN
# 11490       3-я Рощинская       ул      8          20  1745531     NaN
# 13552   2-я Марьиной Рощи       ул      8          20  1735753     NaN
# 13592  17-й Марьиной Рощи   проезд      8          20  1730203     NaN
# 17658  14-й Марьиной Рощи   проезд      8          20  1727994     NaN
# 18150       1-й Рощинский   проезд      8          23  1730710     NaN
# 19796       6-й Рощинский   проезд      8          20  1735389     NaN
# 19808   3-я Марьиной Рощи       ул      8          20  1739541     NaN
# 20434       2-й Рощинский   проезд      8          20  1726354     NaN
# 21082       2-я Рощинская       ул      8          20  1733595     NaN
# 21934  13-й Марьиной Рощи   проезд      8          20  1732711     NaN
#
#        UPDATEDATE   STARTDATE     ENDDATE  ISACTUAL  ISACTIVE
# 368    2020-08-31  2020-08-31  2079-06-06         1         1
# 1138   2020-08-31  2020-08-31  2079-06-06         1         1
# 1146   2016-05-24  1900-01-01  2079-06-06         1         1
# 1169   2020-08-31  2020-08-31  2079-06-06         1         1
# 1811   2020-08-31  2020-08-31  2079-06-06         1         1
# 2258   2019-05-16  2019-05-15  2079-06-06         1         0
# 2394   2016-05-24  1900-01-01  2079-06-06         1         1
# 2936   2020-09-08  2020-09-08  2079-06-06         1         1
# 3208   2016-05-24  1900-01-01  2079-06-06         1         1
# 3763   2016-06-07  2016-06-07  2079-06-06         1         1
# 4546   2020-08-27  2020-08-27  2079-06-06         1         1
# 5923   2020-08-31  2020-08-31  2079-06-06         1         1
# 6030   2020-08-31  2020-08-31  2079-06-06         1         1
# 7344   2020-08-31  2020-08-31  2079-06-06         1         1
# 8804   2020-09-02  2020-09-02  2079-06-06         1         1
# 8810   2020-08-31  2020-08-31  2079-06-06         1         1
# 9401   2020-08-31  2020-08-31  2079-06-06         1         1
# 9454   2020-08-31  2020-08-31  2079-06-06         1         1
# 10149  2020-08-31  2020-08-31  2079-06-06         1         1
# 11490  2020-08-27  2020-08-27  2079-06-06         1         1
# 13552  2020-08-31  2020-08-31  2079-06-06         1         1
# 13592  2020-08-31  2020-08-31  2079-06-06         1         1
# 17658  2020-08-31  2020-08-31  2079-06-06         1         1
# 18150  2020-09-08  2020-09-08  2079-06-06         1         1
# 19796  2020-08-27  2020-08-27  2079-06-06         1         1
# 19808  2020-08-31  2020-08-31  2079-06-06         1         1
# 20434  2020-08-27  2020-08-27  2079-06-06         1         1
# 21082  2020-08-27  2020-08-27  2079-06-06         1         1
# 21934  2020-08-31  2020-08-31  2079-06-06         1         1

# %% [markdown]
# Посмотрим, что с Черёмушками.
#
# Ох, это бинго из проблем.
#
# Во-первых, е-ё. Во-вторых, кварталы. В-третьих, непонятная улица.

# %%
address_parts_dataset[address_parts_dataset["NAME"].apply(lambda x: "черёмушки" in x.lower())]
# Out:
#             ID  OBJECTID                            OBJECTGUID   CHANGEID  \
# 12648  1730592   1406121  0549b212-4010-46eb-9bb0-2d0a4f953a32    3848737
# 19132  1073061    868638  2abea417-e475-439d-b186-18d10ea60efd    2401720
# 20478  1733906   1408786  bb230068-82f9-4306-9a11-6c271360cbce    3855002
# 21630  1864732   1399879  1a329f12-8a04-4e7d-9135-1885355f66e0  156333122
#
#                          NAME TYPENAME  LEVEL  OPERTYPEID   PREVID  NEXTID  \
# 12648      Новочерёмушкинская       ул      8          20  1730550     0.0
# 19132               Черёмушки       ул      8          20  1072986     0.0
# 20478          Черёмушкинский   проезд      8          20  1733819     0.0
# 21630  Большая Черёмушкинская       ул      8          23  1722985     NaN
#
#        UPDATEDATE   STARTDATE     ENDDATE  ISACTUAL  ISACTIVE
# 12648  2016-06-10  2016-06-09  2079-06-06         1         1
# 19132  2016-10-05  2016-06-14  2079-06-06         1         1
# 20478  2019-12-15  2016-06-09  2079-06-06         1         1
# 21630  2020-09-08  2020-09-08  2079-06-06         1         1

# %%
address_parts_dataset[address_parts_dataset["NAME"].apply(lambda x: "черемушки" in x.lower())]
# Out:
#              ID  OBJECTID                            OBJECTGUID   CHANGEID  \
# 954    52131903   1403697  89830603-21f6-43c4-832c-e518b9405e0c  604654869
# 1782    1905013   1408494  4d466794-05e3-419e-8ccf-550fb69a3201  184560370
# 2460    1905008   1407246  1d60272e-5108-4838-834e-c59fad72e0a5  184560365
# 2464    1905108   1414319  e435b197-2ecf-4fc8-b631-ae0d34655ef2  184560471
# 7186   52126882   1411098  5d3d8cc9-d3d2-427d-b2e4-2ab327703749  601215520
# 9631    1059107    860441  b37451ee-c6fb-4f9d-bb45-781fd83d5b07    2371235
# 13041  52100364    874727  d7a8107b-2f18-4bfd-b230-fed13480bc4e  590990357
# 14517  52110173    865343  faa1e403-770e-427c-a061-81e0136f4e14  595714449
# 14643   1823214  95251317  b8643c8b-a039-4e7c-a800-db69493f95b8  138207834
# 22054  52100231   1404480  1e0c9150-df45-4214-b1c4-7c1e7adf49b8  590970545
#
#                                 NAME   TYPENAME  LEVEL  OPERTYPEID   PREVID  \
# 954              32а Новые Черемушки       кв-л      7          30  1727651
# 1782           Новые Черемушки 22-23       кв-л      8          30  1733470
# 2460           Новые Черемушки 29-30       кв-л      8          30  1731940
# 2464           Новые Черемушки 24-25       кв-л      8          30  1740874
# 7186                   ДПК Черемушки       тер.      7          30  1736669
# 9631                  Черемушкинская         ул      8           1        0
# 13041                  ДПК Черемушки        тер      7          30  1082863
# 14517          СПК Ветеран-Черемушки        тер      8          30  1067420
# 14643  муниципальный округ Черемушки  вн.тер.г.      3           0        0
# 22054            Новые Черемушки 24а       кв-л      8          30  1728497
#
#        NEXTID  UPDATEDATE   STARTDATE     ENDDATE  ISACTUAL  ISACTIVE
# 954       0.0  2024-10-15  2024-10-15  2079-06-06         1         0
# 1782      0.0  2021-04-05  2017-11-16  2079-06-06         1         0
# 2460      0.0  2021-04-05  2017-11-16  2079-06-06         1         0
# 2464      0.0  2021-04-05  2017-11-16  2079-06-06         1         0
# 7186      0.0  2024-09-13  2024-09-13  2079-06-06         1         0
# 9631      0.0  2017-09-07  1900-01-01  2079-06-06         1         1
# 13041     0.0  2024-02-27  2024-02-27  2079-06-06         1         0
# 14517     0.0  2024-05-15  2024-05-15  2079-06-06         1         0
# 14643     0.0  2011-01-01  2011-01-01  2079-06-06         1         1
# 22054     0.0  2024-02-26  2024-02-26  2079-06-06         1         0

# %% [markdown]
# Улица Черёмушки -- в Щербинке.

# %%
object_id = 868638

# %%
address_parts_dataset[address_parts_dataset["OBJECTID"] == object_id]
# Out:
#             ID  OBJECTID                            OBJECTGUID  CHANGEID  \
# 19132  1073061    868638  2abea417-e475-439d-b186-18d10ea60efd   2401720
#
#             NAME TYPENAME  LEVEL  OPERTYPEID   PREVID  NEXTID  UPDATEDATE  \
# 19132  Черёмушки       ул      8          20  1072986     0.0  2016-10-05
#
#         STARTDATE     ENDDATE  ISACTUAL  ISACTIVE
# 19132  2016-06-14  2079-06-06         1         1

# %%
mun_dataset[mun_dataset["OBJECTID"] == object_id]
# Out:
#       OBJECTID         ID  PARENTOBJID   CHANGEID     OKTMO    PREVID  NEXTID  \
# 1834    868638  242830763     865977.0  619680948  45932000  29949231       0
#
#       UPDATEDATE   STARTDATE     ENDDATE  ISACTIVE  \
# 1834  2025-01-27  2025-01-27  2079-06-06         1
#
#                                 PATH
# 1834  1405113.95251374.865977.868638

# %%
adm_dataset[adm_dataset["OBJECTID"] == object_id]
# Out:
#       OBJECTID         ID  PARENTOBJID   CHANGEID  REGIONCODE    PREVID  \
# 1960    868638  241226974       865977  619680948          77  97481267
#
#       NEXTID  UPDATEDATE   STARTDATE     ENDDATE  ISACTIVE  \
# 1960       0  2025-01-27  2025-01-27  2079-06-06         1
#
#                                  PATH  AREACODE  CITYCODE  PLACECODE  \
# 1960  1405113.169509311.865977.868638      27.0       0.0        7.0
#
#       PLANCODE  STREETCODE
# 1960       0.0         2.0

# %%
address_parts_dataset[address_parts_dataset["OBJECTID"].isin([int(i) for i in "1405113.95251374.865977.868638".split(".")])]
# Out:
#              ID  OBJECTID                            OBJECTGUID   CHANGEID  \
# 2558    1068536    865977  1e43ba77-1904-4b1f-a3f6-f23df5c0c5b4    2391799
# 9068    1729288   1405113  0c5b2444-70a0-4932-980c-b4dc0d3f02b5    3846120
# 14644  52144898  95251374  89184dde-a93f-40ae-b6d5-8645833bddb3  613527978
# 19132   1073061    868638  2abea417-e475-439d-b186-18d10ea60efd    2401720
#
#                                NAME   TYPENAME  LEVEL  OPERTYPEID   PREVID  \
# 2558                          Ерино          д      6           1        0
# 9068                         Москва          г      1           1        0
# 14644  муниципальный округ Щербинка  вн.тер.г.      3          20  1823271
# 19132                     Черёмушки         ул      8          20  1072986
#
#        NEXTID  UPDATEDATE   STARTDATE     ENDDATE  ISACTUAL  ISACTIVE
# 2558      0.0  2016-09-26  1900-01-01  2079-06-06         1         1
# 9068      0.0  2018-09-01  1900-01-01  2079-06-06         1         1
# 14644     NaN  2024-12-26  2024-12-26  2079-06-06         1         1
# 19132     0.0  2016-10-05  2016-06-14  2079-06-06         1         1

# %%
address_parts_dataset[address_parts_dataset["OBJECTID"].isin([int(i) for i in "1405113.169509311.865977.868638".split(".")])]
# Out:
#              ID   OBJECTID                            OBJECTGUID   CHANGEID  \
# 2558    1068536     865977  1e43ba77-1904-4b1f-a3f6-f23df5c0c5b4    2391799
# 9068    1729288    1405113  0c5b2444-70a0-4932-980c-b4dc0d3f02b5    3846120
# 14483  52147930  169509311  2c2f107f-ebf2-46f9-8975-7c2ebf70bd9b  617838291
# 19132   1073061     868638  2abea417-e475-439d-b186-18d10ea60efd    2401720
#
#             NAME TYPENAME  LEVEL  OPERTYPEID   PREVID  NEXTID  UPDATEDATE  \
# 2558       Ерино        д      6           1        0     0.0  2016-09-26
# 9068      Москва        г      1           1        0     0.0  2018-09-01
# 14483   Щербинка      р-н      2          10        0     0.0  2025-01-16
# 19132  Черёмушки       ул      8          20  1072986     0.0  2016-10-05
#
#         STARTDATE     ENDDATE  ISACTUAL  ISACTIVE
# 2558   1900-01-01  2079-06-06         1         1
# 9068   1900-01-01  2079-06-06         1         1
# 14483  2025-01-16  2079-06-06         1         1
# 19132  2016-06-14  2079-06-06         1         1

# %% [markdown]
# С кварталом ещё любопытнее. Впрочем, он не активный, можно его попробовать проигнорить.

# %%
object_id = 1408494

# %%
address_parts_dataset[address_parts_dataset["OBJECTID"] == object_id]
# Out:
#            ID  OBJECTID                            OBJECTGUID   CHANGEID  \
# 1782  1905013   1408494  4d466794-05e3-419e-8ccf-550fb69a3201  184560370
#
#                        NAME TYPENAME  LEVEL  OPERTYPEID   PREVID  NEXTID  \
# 1782  Новые Черемушки 22-23     кв-л      8          30  1733470     0.0
#
#       UPDATEDATE   STARTDATE     ENDDATE  ISACTUAL  ISACTIVE
# 1782  2021-04-05  2017-11-16  2079-06-06         1         0

# %%
mun_dataset[mun_dataset["OBJECTID"] == object_id]
# Out:
#       OBJECTID        ID  PARENTOBJID  CHANGEID     OKTMO  PREVID  NEXTID  \
# 5450   1408494  56601063   95251317.0  44132858  45908000       0       0
#
#       UPDATEDATE   STARTDATE     ENDDATE  ISACTIVE                      PATH
# 5450  1900-01-01  1900-01-01  2079-06-06         0  1405113.95251317.1408494

# %%
adm_dataset[adm_dataset["OBJECTID"] == object_id]
# Out:
#       OBJECTID        ID  PARENTOBJID  CHANGEID  REGIONCODE  PREVID  NEXTID  \
# 5611   1408494  96588516      1405113   3854177          77       0       0
#
#       UPDATEDATE   STARTDATE     ENDDATE  ISACTIVE             PATH  AREACODE  \
# 5611  1900-01-01  1900-01-01  2079-06-06         0  1405113.1408494       0.0
#
#       CITYCODE  PLACECODE  PLANCODE  STREETCODE
# 5611       0.0        0.0       0.0      4127.0

# %%
address_parts_dataset[address_parts_dataset["OBJECTID"].isin([int(i) for i in "1405113.95251317.1408494".split(".")])]
# Out:
#             ID  OBJECTID                            OBJECTGUID   CHANGEID  \
# 1782   1905013   1408494  4d466794-05e3-419e-8ccf-550fb69a3201  184560370
# 9068   1729288   1405113  0c5b2444-70a0-4932-980c-b4dc0d3f02b5    3846120
# 14643  1823214  95251317  b8643c8b-a039-4e7c-a800-db69493f95b8  138207834
#
#                                 NAME   TYPENAME  LEVEL  OPERTYPEID   PREVID  \
# 1782           Новые Черемушки 22-23       кв-л      8          30  1733470
# 9068                          Москва          г      1           1        0
# 14643  муниципальный округ Черемушки  вн.тер.г.      3           0        0
#
#        NEXTID  UPDATEDATE   STARTDATE     ENDDATE  ISACTUAL  ISACTIVE
# 1782      0.0  2021-04-05  2017-11-16  2079-06-06         1         0
# 9068      0.0  2018-09-01  1900-01-01  2079-06-06         1         1
# 14643     0.0  2011-01-01  2011-01-01  2079-06-06         1         1

# %% [markdown]
# А кто в квартале?

# %%
mun_dataset[mun_dataset["PARENTOBJID"] == object_id][["OBJECTID"]].merge(houses_dataset, on="OBJECTID")
# Out:
#    OBJECTID        ID                            OBJECTGUID   CHANGEID  \
# 0  28715400  70892291  2f76a26b-84d3-4875-bff6-16e8f059e60c  182544464
# 1  28715853  70892292  1722c860-b5b3-4154-9332-388fd28adbbc  182544465
# 2  28716803  70553191  e8040565-cb44-4268-b8df-5bc06631b69a  182205357
# 3  28717170  70892293  392de842-4c6e-4893-a8e1-8d5c8cbd0ad1  182544466
# 4  28717927  70553195  ef24b4e2-5f2e-4c13-a61e-9bd4fe2ca632  182205361
# 5  28718734  70553196  a69452cb-02ba-4962-9a5e-e01be13b12cf  182205362
# 6  28719152  70553199  3b9dd01c-5c7f-426c-b95a-f72f016f67b2  182205365
#
#   HOUSENUM ADDNUM1  HOUSETYPE  ADDTYPE1  OPERTYPEID    PREVID  NEXTID  \
# 0      к1В       1        2.0       2.0          30  17034077     0.0
# 1     None       1        NaN       1.0          30  17034415     0.0
# 2     None      1Г        NaN       1.0          30  17034984     0.0
# 3       к5       1        2.0       2.0          30  17035154     0.0
# 4     None      1В        NaN       1.0          30  17035712     0.0
# 5     None      1А        NaN       1.0          30  17036388     0.0
# 6     None      1Б        NaN       1.0          30  17036725     0.0
#
#    UPDATEDATE   STARTDATE     ENDDATE  ISACTUAL  ISACTIVE ADDNUM2  ADDTYPE2
# 0  2021-03-16  1900-01-01  2079-06-06         1         0    None       NaN
# 1  2021-03-16  1900-01-01  2079-06-06         1         0    None       NaN
# 2  2021-03-16  1900-01-01  2079-06-06         1         0    None       NaN
# 3  2021-03-16  1900-01-01  2079-06-06         1         0    None       NaN
# 4  2021-03-16  1900-01-01  2079-06-06         1         0    None       NaN
# 5  2021-03-16  1900-01-01  2079-06-06         1         0    None       NaN
# 6  2021-03-16  1900-01-01  2079-06-06         1         0    None       NaN

# %% [markdown]
# Наконец, было интересно, к каким районам отнесут улицы, проходящие через несколько?
#
# Ленинский проспект уж точно лежит в нескольких.

# %%
address_parts_dataset[address_parts_dataset["NAME"].apply(lambda x: "ленинский" in x.lower())]
# Out:
#            ID  OBJECTID                            OBJECTGUID  CHANGEID  \
# 9238  1726229   1402585  5f2a1243-a57b-418e-baee-ff76f4993b45   3839686
#
#            NAME TYPENAME  LEVEL  OPERTYPEID  PREVID  NEXTID  UPDATEDATE  \
# 9238  Ленинский    пр-кт      8           1       0     0.0  2016-05-17
#
#        STARTDATE     ENDDATE  ISACTUAL  ISACTIVE
# 9238  1900-01-01  2079-06-06         1         1

# %%
object_id = 1402585

# %% [markdown]
# Административно он в Москве, логично.

# %%
adm_dataset[adm_dataset["OBJECTID"] == object_id]
# Out:
#       OBJECTID         ID  PARENTOBJID   CHANGEID  REGIONCODE    PREVID  \
# 3396   1402585  114977976      1405113  154399119          77  92425072
#
#       NEXTID  UPDATEDATE   STARTDATE     ENDDATE  ISACTIVE             PATH  \
# 3396       0  2020-08-11  2020-08-11  2079-06-06         1  1405113.1402585
#
#       AREACODE  CITYCODE  PLACECODE  PLANCODE  STREETCODE
# 3396       0.0       0.0        0.0       0.0      1689.0

# %%
address_parts_dataset[address_parts_dataset["OBJECTID"] == 1405113]
# Out:
#            ID  OBJECTID                            OBJECTGUID  CHANGEID  \
# 9068  1729288   1405113  0c5b2444-70a0-4932-980c-b4dc0d3f02b5   3846120
#
#         NAME TYPENAME  LEVEL  OPERTYPEID  PREVID  NEXTID  UPDATEDATE  \
# 9068  Москва        г      1           1       0     0.0  2018-09-01
#
#        STARTDATE     ENDDATE  ISACTUAL  ISACTIVE
# 9068  1900-01-01  2079-06-06         1         1

# %% [markdown]
# А муниципально? Только один район?

# %%
mun_dataset[mun_dataset["OBJECTID"] == object_id]
# Out:
#       OBJECTID        ID  PARENTOBJID   CHANGEID     OKTMO  PREVID  NEXTID  \
# 3248   1402585  54625348   95251336.0  125126761  45907000       0       0
#
#       UPDATEDATE   STARTDATE     ENDDATE  ISACTIVE                      PATH
# 3248  1900-01-01  1900-01-01  2079-06-06         1  1405113.95251336.1402585

# %%
address_parts_dataset[address_parts_dataset["OBJECTID"] == 95251336]
# Out:
#            ID  OBJECTID                            OBJECTGUID   CHANGEID  \
# 2772  1823233  95251336  3e970108-c4e6-4e34-bf81-66cd89d70ff1  138207853
#
#                                  NAME   TYPENAME  LEVEL  OPERTYPEID  PREVID  \
# 2772  муниципальный округ Теплый Стан  вн.тер.г.      3           0       0
#
#       NEXTID  UPDATEDATE   STARTDATE     ENDDATE  ISACTUAL  ISACTIVE
# 2772     0.0  2011-01-01  2011-01-01  2079-06-06         1         1

# %% [markdown]
# А вот если взять дома по нему и пути к ним -- то найдутся все районы.

# %%
address_parts_dataset[address_parts_dataset["OBJECTID"].isin(mun_dataset[mun_dataset["PARENTOBJID"] == object_id]["PATH"].apply(lambda x: int(x.split(".")[1])).unique())]
# Out:
#             ID  OBJECTID                            OBJECTGUID   CHANGEID  \
# 1503   1823242  95251345  bee3d09c-1a66-4562-bc87-03412adb6a05  138207862
# 2130   1823213  95251316  7c2651cc-5604-4da1-a1a3-6b984e82b8e3  138207833
# 2772   1823233  95251336  3e970108-c4e6-4e34-bf81-66cd89d70ff1  138207853
# 3565   1823135  95251238  48f3ec88-9e75-4f97-acde-cb8b8a752df0  138207755
# 9200   1823236  95251339  c43b8810-62da-4ff3-a78a-667669718830  138207856
# 15197  1823227  95251330  ac38fe1c-643f-4314-826f-1ef5c0e37971  138207847
# 20191  1823166  95251269  7658016e-ce69-4165-ac67-75bf9df5e020  138207786
# 22204  1823212  95251315  770c4ffa-0fb7-4fd1-b0ac-b688cfdbe166  138207832
#
#                                            NAME   TYPENAME  LEVEL  OPERTYPEID  \
# 1503   муниципальный округ Проспект Вернадского  вн.тер.г.      3           0
# 2130     муниципальный округ Тропарево-Никулино  вн.тер.г.      3           0
# 2772            муниципальный округ Теплый Стан  вн.тер.г.      3           0
# 3565               муниципальный округ Якиманка  вн.тер.г.      3           0
# 9200            муниципальный округ Гагаринский  вн.тер.г.      3           0
# 15197           муниципальный округ Обручевский  вн.тер.г.      3           0
# 20191               муниципальный округ Донской  вн.тер.г.      3           0
# 22204         муниципальный округ Ломоносовский  вн.тер.г.      3           0
#
#        PREVID  NEXTID  UPDATEDATE   STARTDATE     ENDDATE  ISACTUAL  ISACTIVE
# 1503        0     0.0  2011-01-01  2011-01-01  2079-06-06         1         1
# 2130        0     0.0  2011-01-01  2011-01-01  2079-06-06         1         1
# 2772        0     0.0  2011-01-01  2011-01-01  2079-06-06         1         1
# 3565        0     0.0  2011-01-01  2011-01-01  2079-06-06         1         1
# 9200        0     0.0  2011-01-01  2011-01-01  2079-06-06         1         1
# 15197       0     0.0  2011-01-01  2011-01-01  2079-06-06         1         1
# 20191       0     0.0  2011-01-01  2011-01-01  2079-06-06         1         1
# 22204       0     0.0  2011-01-01  2011-01-01  2079-06-06         1         1

# %% [markdown]
# # Подготовка итоговых данных

# %% [markdown]
# Итак, для дальнейшего поиска мы сохраним таблицу с записями вида:
# * object_id,
# * номер дома,
# * тип дома,
# * добавочный номер 1,
# * добавочный тип 1,
# * добавочный номер 2,
# * добавочный тип 2,
# * название дороги,
# * тип дороги,
# * is_active.
#
# И другую таблицу:
# * objectid,
# * тэг.
#
# Добавим пару слов про тэги. Нам хочется, не ограничивая себя, хранить информацию о районе -- и шире, о регионе. При этом мы не хотим сопоставлять каждому дому только один тэг. Более того, хочется иметь возможность добавить в дальнейшем отдельную выгрузку с новым тэгом. Таким образом в отдельной таблице мы будем сопоставлять дома тэгам и применять затем фильтры по тэгам. Использовать мы будем всегда пересечение двух таблиц.

# %% [markdown]
# Поскольку нет уверенности, что в разных регионах нам понадобится одинаковая структура, мы не будем реализовывать универсальный скрипт для обработки всех регионов, а ad-hoc соберём данные по интересующему нас в первую очередь региону -- Москве.

# %% [markdown]
# ## Распаковка нужных данных

# %%
house_types_ds = load_dataset(z, root_files[3])
subhouse_types_ds = load_dataset(z, root_files[0])

# %%
region_id = "77"
region_files = [f for f in z_files if os.path.dirname(f) == region_id]

# %%
# %%time
address_parts_dataset = load_dataset(z, region_files[0])
houses_dataset = load_dataset(z, region_files[9])
mun_dataset = load_dataset(z, region_files[11], "OBJECTID")
# Out:
# CPU times: total: 4min 10s
# Wall time: 4min 12s

# %% [markdown]
# ## Соберём данные вместе

# %% [markdown]
# Всю информацию о домах:

# %%
houses_dataset.shape
# Out:
# (347713, 18)

# %%
houses_joint_info_ds = houses_dataset[[
        "OBJECTID", "HOUSENUM", "HOUSETYPE", "ADDNUM1", "ADDTYPE1", "ADDNUM2", "ADDTYPE2", "ISACTIVE"
    ]].merge(
        mun_dataset[["OBJECTID", "PARENTOBJID", "ISACTIVE", "PATH"]].rename(columns={"ISACTIVE": "ISACTIVE_MUN"}),
        on="OBJECTID",
    ).merge(
        house_types_ds[["ID", "SHORTNAME", "ISACTIVE"]].rename(columns={"ISACTIVE": "ISACTIVE_HTYPES", "ID": "HOUSETYPE", "SHORTNAME": "HSHORTNAME"}),
        on="HOUSETYPE",
    ).merge(
        subhouse_types_ds[["ID", "SHORTNAME", "ISACTIVE"]].rename(columns={"ISACTIVE": "ISACTIVE_ADDTYPES1", "ID": "ADDTYPE1", "SHORTNAME": "A1SHORTNAME"}),
        on="ADDTYPE1",
        how="left",
    ).merge(
        subhouse_types_ds[["ID", "SHORTNAME", "ISACTIVE"]].rename(columns={"ISACTIVE": "ISACTIVE_ADDTYPES2", "ID": "ADDTYPE2", "SHORTNAME": "A2SHORTNAME"}),
        on="ADDTYPE2",
        how="left",
    )

# %%
len(houses_joint_info_ds) / len(houses_dataset)
# Out:
# 0.9961002320879576

# %% [markdown]
# Выделим родителей домов и назовём их условно улицами.

# %%
streets_info_ds = houses_joint_info_ds[[
        "PARENTOBJID"
    ]].drop_duplicates().merge(
        address_parts_dataset[[
            "OBJECTID", "NAME", "TYPENAME", "LEVEL", "ISACTIVE"
        ]].rename(columns={"ISACTIVE": "ISACTIVE_STREET", "OBJECTID": "PARENTOBJID", "NAME": "STREETNAME", "TYPENAME": "STREETTYPENAME"}),
    )

# %%
streets_info_ds.groupby(
    ["LEVEL", "STREETTYPENAME"], as_index=False
)[
    "PARENTOBJID"
].count().sort_values(
    by="PARENTOBJID", ascending=False
).head(10)
# Out:
#     LEVEL STREETTYPENAME  PARENTOBJID
# 50      8             ул         3268
# 11      7           кв-л         1691
# 38      8            пер          714
# 44      8         проезд          440
# 3       6              д          222
# 19      7           тер.          198
# 18      7            тер          169
# 29      8             км          152
# 42      8           пр-д           79
# 40      8             пл           75

# %%
streets_info_ds[
    streets_info_ds["ISACTIVE_STREET"]==1
].groupby(
    ["LEVEL", "STREETTYPENAME"], as_index=False
)[
    "PARENTOBJID"
].count().sort_values(
    by="PARENTOBJID", ascending=False
).head(10)
# Out:
#     LEVEL STREETTYPENAME  PARENTOBJID
# 42      8             ул         3150
# 9       7           кв-л         1185
# 30      8            пер          702
# 36      8         проезд          424
# 3       6              д          219
# 24      8             км          144
# 34      8           пр-д           79
# 32      8             пл           74
# 21      8            б-р           73
# 5       6              п           65

# %% [markdown]
# Осталось для домов определить районы:

# %%
house_to_all_mun_ds = houses_joint_info_ds.assign(
    ANCESTORID=houses_joint_info_ds.PATH.apply(lambda x: [int(a) for a in x.split(".")][:-1])
)[[
    "OBJECTID", "ANCESTORID"
]].explode(
    "ANCESTORID"
).merge(
    address_parts_dataset[
        address_parts_dataset["LEVEL"] == 3
    ][["OBJECTID", "NAME"]].rename(
        columns={"OBJECTID": "ANCESTORID", "NAME": "AREANAME"}
    ),
    on="ANCESTORID",
)[[
    "OBJECTID", "AREANAME"
]]

# %% [markdown]
# ## Сохраним нужные таблицы

# %%
data_path = os.path.join(os.path.dirname(os.getcwd()), "data")
sep = "\t"

# %% [markdown]
# ### Таблица с адресами

# %%
house_addresses_path = os.path.join(data_path, "77_ha.tsv")

# %%
prepared_dataset = houses_joint_info_ds.merge(
    streets_info_ds, on="PARENTOBJID"
)

# %%
prepared_dataset["is_active"] = (
    (prepared_dataset[["ISACTIVE", "ISACTIVE_MUN", "ISACTIVE_STREET"]].min(axis=1) == 1)
    & ~(prepared_dataset[['ISACTIVE_HTYPES', 'ISACTIVE_ADDTYPES1', 'ISACTIVE_ADDTYPES2']] == False).max(axis=1)
)

# %%
prepared_dataset[[
    "OBJECTID", "STREETNAME", "STREETTYPENAME", "HOUSENUM", "HSHORTNAME", "ADDNUM1", "A1SHORTNAME", "ADDNUM2", "A2SHORTNAME", "is_active"
]].rename(
    columns={
        "OBJECTID": "oid",
        "STREETNAME": "street_name",
        "STREETTYPENAME": "street_type",
        "HOUSENUM": "house_num",
        "HSHORTNAME": "house_type",
        "ADDNUM1": "house_add_1_num",
        "A1SHORTNAME": "house_add_1_type",
        "ADDNUM2": "house_add_2_num",
        "A2SHORTNAME": "house_add_2_type",
    }
).to_csv(house_addresses_path, sep=sep, index=False)

# %% [markdown]
# ### Таблица с тэгами

# %%
house_tags_path = os.path.join(data_path, "77_ht.tsv")

# %% [markdown]
# Добавим некоторые вариации.

# %%
areas_ds = house_to_all_mun_ds[house_to_all_mun_ds["AREANAME"].apply(lambda x: x.startswith("муниципальный округ"))].copy()

# %%
areas_ds["AREANAME"] = areas_ds["AREANAME"].apply(lambda x: x.replace("муниципальный округ", "").strip())

# %%
moscow_ds = house_to_all_mun_ds.copy()
moscow_ds["AREANAME"] = "Москва"

# %%
pd.concat([
    house_to_all_mun_ds,
    areas_ds,
    moscow_ds,
], ignore_index=True
).rename(
    columns={"OBJECTID": "oid", "AREANAME": "tag"}
).to_csv(house_tags_path, sep=sep, index=False)
